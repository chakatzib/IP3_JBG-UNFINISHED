# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
simpleList=[3,7,8,9,12]
plt.plot(simpleList)

# %%
listx=[4,0,2,4,3]
listy=[1,2,5,0,9]
plt.plot(listx,listy)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.subplots(ax1,ax2)
#       2 ax1=listx
#       3 ax2=listy
#
# File ~\anaconda3\envs\DS160-01\lib\site-packages\matplotlib\pyplot.py:1502, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1358 """
#    1359 Create a figure and a set of subplots.
#    1360
#    (...)
#    1499
#    1500 """
#    1501 fig = figure(**fig_kw)
# -> 1502 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1503                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1504                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1505                    width_ratios=width_ratios)
#    1506 return fig, axs
#
# ...

# %%
fig=plt.figure(figsize=(5,5))
ax1=fig.add_subplot(151)
ax1.plot(listx)
ax2=fig.add_subplot(511)
ax2.plot(listy)

# %%
X=np.linspace(0,100,101)
Xsquare=X**2
fig=plt.figure(figsize=(16,8))

ax1=fig.add_subplot(121) 
ax1.set_title("X")
ax1.plot(['X'],
        
        color='green')

ax2=fig.add_subplot(122) 
ax2.set_title("X^2")
ax2.plot(['X**2'],
        
        color='purple')

# %%
#scatter plot of x and exponential of x

# %%
Car_Sales=pd.read_csv("car-sales.csv")

# %%
Car_Sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   $4,000
# 1   Honda    Red          87899      4   $5,000
# 2  Toyota   Blue          32549      3   $7,000
# 3     BMW  Black          11179      5  $22,000
# 4  Nissan  White         213095      4   $3,500

# %%
Car_Sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
Car_Sales.plot('Price')
# Out:
# <Axes: xlabel='Price'>

# %%
Car_Sales.plot('Odometer (KM)')
# Out:
# <Axes: xlabel='Odometer (KM)'>

# %%
# One works because it is data that can be properly graphed on a line, while odometer doesnt.
